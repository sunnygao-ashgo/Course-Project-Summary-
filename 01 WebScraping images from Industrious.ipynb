# %%
import os
import re
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# ## Location page

# %%
url = "https://www.industriousoffice.com/locations"
page = BeautifulSoup(requests.get(url).content,'lxml')

# %%
# get location links
loc_links_ls = list()

locations = page.find_all('a',{'class':'gtm-all-locations-link'})
for loc in locations:
    link = loc.get('href')
    name = loc.get_text()
    loc_links_ls.append((name, link))

# %%
loc_links_ls
# Out:
# [('Phoenix', 'https://www.industriousoffice.com/m/phoenix'),
#  ('Scottsdale  Fashion Square',
#   'https://www.industriousoffice.com/l/phoenix/fashion-square/7014-east-camelback-rd'),
#  ('Scottsdale  Old Town',
#   'https://www.industriousoffice.com/l/phoenix/old-town/4250-n-drinkwater-blvd'),
#  ('  Mill Ave',
#   'https://www.industriousoffice.com/l/phoenix/tempe/222-south-mill-ave'),
#  ('  Biltmore',
#   'https://www.industriousoffice.com/l/phoenix/biltmore/2801-e-camelback-road'),
#  ('Los Angeles', 'https://www.industriousoffice.com/m/los-angeles'),
#  ('  Pasadena  Pasarroyo',
#   'https://www.industriousoffice.com/l/los-angeles/pasarroyo/251-south-lake-ave'),
#  ('  Old Pasadena',
#   'https://www.industriousoffice.com/l/los-angeles/old-pasadena/21-miller-alley'),
#  ('  Century City',
#   'https://www.industriousoffice.com/l/los-angeles/century-city/1925-century-park-e'),
#  ('  Playa District',
#   'https://www.industriousoffice.com/l/los-angeles/playa-district/6060-center-drive'),
#  ('  West Hollywood',
#   'https://www.industriousoffice.com/l/los-angeles/west-hollywood/9255-w-sunset-blvd'),
#  ('  Westwood',
#   'https://www.industriousoffice.com/l/los-angeles/westwood/1100-glendon-avenue'),
#  ('  Downtown Glendale',
#   'https://www.industriousoffice.com/l/los-angeles/downtown-glendale/500-n-brand-blvd'),
#  ('  5th and Flower',
#   'https://www.industriousoffice.com/l/los-angeles/fifth-flower/444-south-flower-st'),
#  ('Orange County', 'https://www.industriousoffice.com/m/orange-county'),
#  ('  Newport Beach',
#   'https://www.industriousoffice.com/l/orange-county/newport-beach/100-bayview-circle'),
#  ('  3090 Bristol Street',
#   'https://www.industriousoffice.com/l/orange-county/3090-bristol-street'),
#  ('  Aliso Viejo',
#   'https://www.industriousoffice.com/l/orange-county/aliso-viejo/65-enterprise'),
#  ('  Hana by Industrious at Park Place',
#   'https://www.industriousoffice.com/l/orange-county/hana-by-industrious-at-park-place/3349-michelson-drive'),
#  ('  Irvine',
#   'https://www.industriousoffice.com/l/orange-county/irvine/3333-michelson-drive'),
#  ('San Diego', 'https://www.industriousoffice.com/m/san-diego'),
#  ('  Core Columbia',
#   'https://www.industriousoffice.com/l/san-diego/core-columbia/401-west-a-street'),
#  ('San Francisco Bay Area',
#   'https://www.industriousoffice.com/m/san-francisco-bay-area'),
#  ('  Union Square',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/union-square/77-geary-street'),
#  ('  Concord  2001 Clayton',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/concord/2001-clayton-road'),
#  ('  Financial District',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/financial-district/345-california-st'),
#  ('  Embarcadero',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/embarcadero/1700-montgomery-st'),
#  ('  Walnut Creek  Broadway Plaza',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/broadway-plaza/1212-broadway-plaza'),
#  ('Boulder',
#   'https://www.industriousoffice.com/l/boulder/downtown/1919-14th-st'),
#  ('Denver',
#   'https://www.industriousoffice.com/l/denver/central-business-district/1801-california-st'),
#  ('Washington, D.C. Metro',
#   'https://www.industriousoffice.com/m/washington-d-c'),
#  ('  H Street Corridor',
#   'https://www.industriousoffice.com/l/washington-d-c/h-street-corridor/810-7th-street'),
#  ('  Clarendon',
#   'https://www.industriousoffice.com/l/washington-d-c/clarendon/3100-clarendon-boulevard'),
#  ('  Pike  Rose',
#   'https://www.industriousoffice.com/l/washington-dc/pike-rose/north-bethesda/909-rose-avenue'),
#  ('  Mt Vernon Triangle',
#   'https://www.industriousoffice.com/l/washington-d-c/mt-vernon-triangle/650-massachusetts-ave-nw'),
#  ('  Ballston Quarter',
#   'https://www.industriousoffice.com/l/washington-d-c/ballston-quarter/4075-wilson-blvd'),
#  ('  Ballston Exchange',
#   'https://www.industriousoffice.com/l/washington-d-c/ballston/4201-wilson-blvd'),
#  ('  Tysons',
#   'https://www.industriousoffice.com/l/washington-d-c/tysons/1660-international-drive'),
#  ('  Hana by Industrious at National Landing',
#   'https://www.industriousoffice.com/l/washington-d-c/hana-by-industrious-at-national-landing/2451-crystal-drive'),
#  ('  Alexandria Carlyle Tower',
#   'https://www.industriousoffice.com/l/washington-d-c/alexandria-carlyle-tower/2461-eisenhower-ave'),
#  ('  Bethesda  7200 Wisconsin',
#   'https://www.industriousoffice.com/l/washington-d-c/bethesda/7200-wisconsin-ave'),
#  ('  Thomas Circle',
#   'https://www.industriousoffice.com/l/washington-d-c/downtown/one-thomas-circle'),
#  ('  Arlington Court House',
#   'https://www.industriousoffice.com/l/washington-d-c/arlington-court-house/2311-wilson-blvd'),
#  ('Miami', 'https://www.industriousoffice.com/m/miami'),
#  ('  Wynwood',
#   'https://www.industriousoffice.com/l/miami/wynwood/280-nw-28th-street'),
#  ('  Esplanade at Aventura',
#   'https://www.industriousoffice.com/l/miami/esplanade-at-aventura/19505-biscayne-blvd'),
#  ('  Brickell',
#   'https://www.industriousoffice.com/l/miami/brickell/1111-brickel-ave'),
#  ('Orlando',
#   'https://www.industriousoffice.com/l/orlando/orlando/300-south-orange-ave'),
#  ('Tampa Bay', 'https://www.industriousoffice.com/m/tampa'),
#  ('St Petersburg  200 Central Ave',
#   'https://www.industriousoffice.com/l/tampa/st-petersburg/200-central-avenue'),
#  ('Tampa  Sparkman Wharf',
#   'https://www.industriousoffice.com/l/tampa/sparkman-wharf/615-channelside-drive'),
#  ('Tampa  Centro Ybor',
#   'https://www.industriousoffice.com/l/tampa/tampa-centro-ybor/1600-e-eighth-ave'),
#  ('Tampa  Downtown',
#   'https://www.industriousoffice.com/l/tampa/downtown/401-east-jackson-st'),
#  ('Atlanta', 'https://www.industriousoffice.com/m/atlanta'),
#  ('  Downtown  101 Marietta St',
#   'https://www.industriousoffice.com/l/atlanta/downtown/101-marietta-street'),
#  ('  Perimeter',
#   'https://www.industriousoffice.com/l/atlanta/perimeter/7000-central-parkway'),
#  ('  Midtown',
#   'https://www.industriousoffice.com/l/atlanta/midtown/1447-peachtree-st-ne'),
#  ('  Buckhead',
#   'https://www.industriousoffice.com/l/atlanta/buckhead/309-east-paces-ferry-rd-ne'),
#  ('  Monarch Tower',
#   'https://www.industriousoffice.com/l/atlanta/monarch-tower/3424-peachtree-rd-ne'),
#  ('  West Midtown',
#   'https://www.industriousoffice.com/l/atlanta/stockyards/976-brady-ave'),
#  ('  Ponce City Market',
#   'https://www.industriousoffice.com/l/atlanta/ponce/675-ponce-de-leon-ave-ne'),
#  ('Chicago', 'https://www.industriousoffice.com/m/chicago'),
#  ('  Willis Tower',
#   'https://www.industriousoffice.com/l/chicago/willis-tower/233-s-wacker-dr'),
#  ('  Millenium Park',
#   'https://www.industriousoffice.com/l/chicago/millenium-park/24-east-washington-street'),
#  ('  Ogilvie',
#   'https://www.industriousoffice.com/l/chicago/ogilvie/500-west-madison-st'),
#  ('  Evanston',
#   'https://www.industriousoffice.com/l/chicago/evanston/909-davis-street'),
#  ('  Fulton Market',
#   'https://www.industriousoffice.com/l/chicago/fulton-market/171-n-aberdeen-st'),
#  ('  Wicker Park',
#   'https://www.industriousoffice.com/l/chicago/wicker-park/1720-west-division-st'),
#  ('  Central Loop',
#   'https://www.industriousoffice.com/l/chicago/central-loop/231-s-lasalle'),
#  ('Indianapolis', 'https://www.industriousoffice.com/m/indianapolis'),
#  ('  Carmel City Center',
#   'https://www.industriousoffice.com/l/indianapolis/carmel-city/880-monon-green-boulevard'),
#  ('  Mass Ave',
#   'https://www.industriousoffice.com/l/indianapolis/350-massachusetts-ave'),
#  ('Boston', 'https://www.industriousoffice.com/m/boston'),
#  ('  Back Bay',
#   'https://www.industriousoffice.com/l/boston/back-bay/855-boylston-st'),
#  ('  Seaport',
#   'https://www.industriousoffice.com/l/boston/seaport/22-boston-wharf-rd'),
#  ('  Financial District',
#   'https://www.industriousoffice.com/l/boston/financial-district/100-summer-st'),
#  ('  Copley',
#   'https://www.industriousoffice.com/l/boston/copley/131-dartmouth-st'),
#  ('Minneapolis', 'https://www.industriousoffice.com/m/minneapolis'),
#  ('  North Loop',
#   'https://www.industriousoffice.com/l/minneapolis/north-loop/323-washington-avenue-north'),
#  ('  Downtown',
#   'https://www.industriousoffice.com/l/minneapolis/downtown/60-south-sixth-st'),
#  ('Kansas City',
#   'https://www.industriousoffice.com/l/kansas-city/country-club-plaza/420-nichols-rd'),
#  ('North Jersey', 'https://www.industriousoffice.com/m/north-jersey'),
#  ('  Newport Tower',
#   'https://www.industriousoffice.com/l/north-jersey/newport-tower/525-washington-blvd'),
#  ('  Short Hills',
#   'https://www.industriousoffice.com/l/north-jersey/mall-at-short-hills/1200-morris-turnpike'),
#  ('New York City', 'https://www.industriousoffice.com/m/new-york-city'),
#  ('  Tribeca',
#   'https://www.industriousoffice.com/l/new-york-city/tribeca/32-ave-of-the-americas'),
#  ('  WorkLife Office Suites by Industrious',
#   'https://www.industriousoffice.com/industrious-new-york-coworking/new-york-city-worklife-office-suites-powered-by-industrious'),
#  ('  West 30th',
#   'https://www.industriousoffice.com/l/new-york-city/west-30th/251-w-30th-street'),
#  ('  Brooklyn 1000 Dean',
#   'https://www.industriousoffice.com/l/new-york-city/brooklyn/1000-dean-st'),
#  ('  University Place',
#   'https://www.industriousoffice.com/l/new-york-city/university-place/41-east-11th-street'),
#  ('  261 Madison Ave',
#   'https://www.industriousoffice.com/l/new-york-city/261-madison-avenue'),
#  ('  Bryant Park off Fifth',
#   'https://www.industriousoffice.com/l/new-york-city/congregate-by-industrious/25-w-39th-st'),
#  ('  Carnegie Hall Tower',
#   'https://www.industriousoffice.com/l/new-york-city/carnegie-hall-tower/152-west-57th-st'),
#  ('  135 W 50th Street',
#   'https://www.industriousoffice.com/l/new-york-city/135-w-50th-st'),
#  ('  Industrious at Equinox',
#   'https://www.industriousoffice.com/l/new-york-city/equinox/31-hudson-yards'),
#  ('  Hana by Industrious at 3 World Trade Center',
#   'https://www.industriousoffice.com/l/new-york-city/hana-by-industrious-at-3-world-trade-center/175-greenwich-street'),
#  ('  Union Square',
#   'https://www.industriousoffice.com/l/new-york-city/union-square/215-park-avenue-s'),
#  ('  Brooklyn 594 Dean',
#   'https://www.industriousoffice.com/l/new-york-city/brooklyn/594-dean-st'),
#  ('  SoHo West',
#   'https://www.industriousoffice.com/l/new-york-city/soho-west/325-hudson-st'),
#  ('  Bryant Park on Broadway',
#   'https://www.industriousoffice.com/l/new-york-city/bryant-park/1411-broadway'),
#  ('Charlotte', 'https://www.industriousoffice.com/m/charlotte'),
#  ('  Uptown',
#   'https://www.industriousoffice.com/l/charlotte/uptown/101-s-tryon-st'),
#  ('  NoDa',
#   'https://www.industriousoffice.com/l/charlotte/noda/436-e-36th-street'),
#  ('Raleigh', 'https://www.industriousoffice.com/m/raleigh'),
#  ('  Chapel Hill  The Gwendolyn',
#   'https://www.industriousoffice.com/l/raleigh/chapel-hill-the-gwendolyn/101-glen-lennox'),
#  ('  Wells Fargo Capitol Center',
#   'https://www.industriousoffice.com/l/raleigh/wells-fargo-capitol-center/150-fayetteville-st'),
#  ('  Charter Square',
#   'https://www.industriousoffice.com/l/raleigh/charter-square/555-fayetteville-st'),
#  ('Columbus', 'https://www.industriousoffice.com/m/columbus'),
#  ('  The Sutton',
#   'https://www.industriousoffice.com/l/columbus/sutton/875-north-high-st'),
#  ('  The Joseph',
#   'https://www.industriousoffice.com/l/columbus/joseph/629-north-high-st'),
#  ('Portland',
#   'https://www.industriousoffice.com/l/portland/pioneer-square/811-sw-sixth-avenue'),
#  ('Philadelphia', 'https://www.industriousoffice.com/m/philadelphia'),
#  ('  Fashion District',
#   'https://www.industriousoffice.com/l/philadelphia/fashion-district/901-market-street'),
#  ('  Hana by Industrious at 1818 Market Street',
#   'https://www.industriousoffice.com/l/philadelphia/hana-by-industrious/1818-market-street'),
#  ('  Avenue of the Arts',
#   'https://www.industriousoffice.com/l/philadelphia/avenue-of-the-arts/230-s-broad-st'),
#  ('  Two Liberty Place',
#   'https://www.industriousoffice.com/l/philadelphia/two-liberty-place/50-s-sixteenth-st'),
#  ('Pittsburgh', 'https://www.industriousoffice.com/m/pittsburgh'),
#  ('  PPG Place',
#   'https://www.industriousoffice.com/l/pittsburgh/ppg-place/one-ppg-place'),
#  ('  Liberty Center',
#   'https://www.industriousoffice.com/l/pittsburgh/liberty-center/1001-liberty-ave'),
#  ('Nashville', 'https://www.industriousoffice.com/m/nashville'),
#  ('  Downtown',
#   'https://www.industriousoffice.com/l/nashville/downtown/414-union-st'),
#  ('  Gulch',
#   'https://www.industriousoffice.com/l/nashville/gulch/1033-demonbreun-st'),
#  ('Austin', 'https://www.industriousoffice.com/m/austin'),
#  ('  9th and Congress',
#   'https://www.industriousoffice.com/l/austin/9th-congress/823-congress-ave'),
#  ('  5th and Colorado',
#   'https://www.industriousoffice.com/l/austin/5th-colorado/201-west-fifth-st'),
#  ('  San Jacinto Blvd',
#   'https://www.industriousoffice.com/l/austin/98-san-jacinto-blvd'),
#  ('Dallas — Fort Worth', 'https://www.industriousoffice.com/m/dallas'),
#  ('  Dallas Farmers Market',
#   'https://www.industriousoffice.com/l/dallas/farmers-market/910-south-pearl-expressway'),
#  ('  Hana by Industrious at Park District',
#   'https://www.industriousoffice.com/l/dallas/hana-by-industrious-at-park-district/2121-n-pearl-street'),
#  ('  Plano',
#   'https://www.industriousoffice.com/l/dallas/plano/7250-dallas-pkwy'),
#  ('  Arts District',
#   'https://www.industriousoffice.com/l/dallas/arts-district/1722-routh-st'),
#  ('Houston', 'https://www.industriousoffice.com/m/houston'),
#  ('', 'https://www.industriousoffice.com/l/houston/2101-citywest-blvd'),
#  ('Salt Lake City', 'https://www.industriousoffice.com/m/slc'),
#  ('  The Square with Industrious',
#   'https://www.industriousoffice.com/l/slc/the-square/136-s-main-st'),
#  ('Seattle', 'https://www.industriousoffice.com/m/seattle'),
#  ('  Downtown',
#   'https://www.industriousoffice.com/l/seattle/downtown/2033-sixth-avenue'),
#  ('  Bellevue',
#   'https://www.industriousoffice.com/l/seattle/bellevue/500-108th-avenue-ne'),
#  ('Phoenix', 'https://www.industriousoffice.com/m/phoenix'),
#  ('Scottsdale  Fashion Square',
#   'https://www.industriousoffice.com/l/phoenix/fashion-square/7014-east-camelback-rd'),
#  ('Scottsdale  Old Town',
#   'https://www.industriousoffice.com/l/phoenix/old-town/4250-n-drinkwater-blvd'),
#  ('  Mill Ave',
#   'https://www.industriousoffice.com/l/phoenix/tempe/222-south-mill-ave'),
#  ('  Biltmore',
#   'https://www.industriousoffice.com/l/phoenix/biltmore/2801-e-camelback-road'),
#  ('Los Angeles', 'https://www.industriousoffice.com/m/los-angeles'),
#  ('  Pasadena  Pasarroyo',
#   'https://www.industriousoffice.com/l/los-angeles/pasarroyo/251-south-lake-ave'),
#  ('  Old Pasadena',
#   'https://www.industriousoffice.com/l/los-angeles/old-pasadena/21-miller-alley'),
#  ('  Century City',
#   'https://www.industriousoffice.com/l/los-angeles/century-city/1925-century-park-e'),
#  ('  Playa District',
#   'https://www.industriousoffice.com/l/los-angeles/playa-district/6060-center-drive'),
#  ('  West Hollywood',
#   'https://www.industriousoffice.com/l/los-angeles/west-hollywood/9255-w-sunset-blvd'),
#  ('  Westwood',
#   'https://www.industriousoffice.com/l/los-angeles/westwood/1100-glendon-avenue'),
#  ('  Downtown Glendale',
#   'https://www.industriousoffice.com/l/los-angeles/downtown-glendale/500-n-brand-blvd'),
#  ('  5th and Flower',
#   'https://www.industriousoffice.com/l/los-angeles/fifth-flower/444-south-flower-st'),
#  ('Orange County', 'https://www.industriousoffice.com/m/orange-county'),
#  ('  Newport Beach',
#   'https://www.industriousoffice.com/l/orange-county/newport-beach/100-bayview-circle'),
#  ('  3090 Bristol Street',
#   'https://www.industriousoffice.com/l/orange-county/3090-bristol-street'),
#  ('  Aliso Viejo',
#   'https://www.industriousoffice.com/l/orange-county/aliso-viejo/65-enterprise'),
#  ('  Hana by Industrious at Park Place',
#   'https://www.industriousoffice.com/l/orange-county/hana-by-industrious-at-park-place/3349-michelson-drive'),
#  ('  Irvine',
#   'https://www.industriousoffice.com/l/orange-county/irvine/3333-michelson-drive'),
#  ('San Diego', 'https://www.industriousoffice.com/m/san-diego'),
#  ('  Core Columbia',
#   'https://www.industriousoffice.com/l/san-diego/core-columbia/401-west-a-street'),
#  ('San Francisco Bay Area',
#   'https://www.industriousoffice.com/m/san-francisco-bay-area'),
#  ('  Union Square',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/union-square/77-geary-street'),
#  ('  Concord  2001 Clayton',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/concord/2001-clayton-road'),
#  ('  Financial District',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/financial-district/345-california-st'),
#  ('  Embarcadero',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/embarcadero/1700-montgomery-st'),
#  ('  Walnut Creek  Broadway Plaza',
#   'https://www.industriousoffice.com/l/san-francisco-bay-area/broadway-plaza/1212-broadway-plaza'),
#  ('Boulder',
#   'https://www.industriousoffice.com/l/boulder/downtown/1919-14th-st'),
#  ('Denver',
#   'https://www.industriousoffice.com/l/denver/central-business-district/1801-california-st'),
#  ('Washington, D.C. Metro',
#   'https://www.industriousoffice.com/m/washington-d-c'),
#  ('  H Street Corridor',
#   'https://www.industriousoffice.com/l/washington-d-c/h-street-corridor/810-7th-street'),
#  ('  Clarendon',
#   'https://www.industriousoffice.com/l/washington-d-c/clarendon/3100-clarendon-boulevard'),
#  ('  Pike  Rose',
#   'https://www.industriousoffice.com/l/washington-dc/pike-rose/north-bethesda/909-rose-avenue'),
#  ('  Mt Vernon Triangle',
#   'https://www.industriousoffice.com/l/washington-d-c/mt-vernon-triangle/650-massachusetts-ave-nw'),
#  ('  Ballston Quarter',
#   'https://www.industriousoffice.com/l/washington-d-c/ballston-quarter/4075-wilson-blvd'),
#  ('  Ballston Exchange',
#   'https://www.industriousoffice.com/l/washington-d-c/ballston/4201-wilson-blvd'),
#  ('  Tysons',
#   'https://www.industriousoffice.com/l/washington-d-c/tysons/1660-international-drive'),
#  ('  Hana by Industrious at National Landing',
#   'https://www.industriousoffice.com/l/washington-d-c/hana-by-industrious-at-national-landing/2451-crystal-drive'),
#  ('  Alexandria Carlyle Tower',
#   'https://www.industriousoffice.com/l/washington-d-c/alexandria-carlyle-tower/2461-eisenhower-ave'),
#  ('  Bethesda  7200 Wisconsin',
#   'https://www.industriousoffice.com/l/washington-d-c/bethesda/7200-wisconsin-ave'),
#  ('  Thomas Circle',
#   'https://www.industriousoffice.com/l/washington-d-c/downtown/one-thomas-circle'),
#  ('  Arlington Court House',
#   'https://www.industriousoffice.com/l/washington-d-c/arlington-court-house/2311-wilson-blvd'),
#  ('Miami', 'https://www.industriousoffice.com/m/miami'),
#  ('  Wynwood',
#   'https://www.industriousoffice.com/l/miami/wynwood/280-nw-28th-street'),
#  ('  Esplanade at Aventura',
#   'https://www.industriousoffice.com/l/miami/esplanade-at-aventura/19505-biscayne-blvd'),
#  ('  Brickell',
#   'https://www.industriousoffice.com/l/miami/brickell/1111-brickel-ave'),
#  ('Orlando',
#   'https://www.industriousoffice.com/l/orlando/orlando/300-south-orange-ave'),
#  ('Tampa Bay', 'https://www.industriousoffice.com/m/tampa'),
#  ('St Petersburg  200 Central Ave',
#   'https://www.industriousoffice.com/l/tampa/st-petersburg/200-central-avenue'),
#  ('Tampa  Sparkman Wharf',
#   'https://www.industriousoffice.com/l/tampa/sparkman-wharf/615-channelside-drive'),
#  ('Tampa  Centro Ybor',
#   'https://www.industriousoffice.com/l/tampa/tampa-centro-ybor/1600-e-eighth-ave'),
#  ('Tampa  Downtown',
#   'https://www.industriousoffice.com/l/tampa/downtown/401-east-jackson-st'),
#  ('Atlanta', 'https://www.industriousoffice.com/m/atlanta'),
#  ('  Downtown  101 Marietta St',
#   'https://www.industriousoffice.com/l/atlanta/downtown/101-marietta-street'),
#  ('  Perimeter',
#   'https://www.industriousoffice.com/l/atlanta/perimeter/7000-central-parkway'),
#  ('  Midtown',
#   'https://www.industriousoffice.com/l/atlanta/midtown/1447-peachtree-st-ne'),
#  ('  Buckhead',
#   'https://www.industriousoffice.com/l/atlanta/buckhead/309-east-paces-ferry-rd-ne'),
#  ('  Monarch Tower',
#   'https://www.industriousoffice.com/l/atlanta/monarch-tower/3424-peachtree-rd-ne'),
#  ('  West Midtown',
#   'https://www.industriousoffice.com/l/atlanta/stockyards/976-brady-ave'),
#  ('  Ponce City Market',
#   'https://www.industriousoffice.com/l/atlanta/ponce/675-ponce-de-leon-ave-ne'),
#  ('Chicago', 'https://www.industriousoffice.com/m/chicago'),
#  ('  Willis Tower',
#   'https://www.industriousoffice.com/l/chicago/willis-tower/233-s-wacker-dr'),
#  ('  Millenium Park',
#   'https://www.industriousoffice.com/l/chicago/millenium-park/24-east-washington-street'),
#  ('  Ogilvie',
#   'https://www.industriousoffice.com/l/chicago/ogilvie/500-west-madison-st'),
#  ('  Evanston',
#   'https://www.industriousoffice.com/l/chicago/evanston/909-davis-street'),
#  ('  Fulton Market',
#   'https://www.industriousoffice.com/l/chicago/fulton-market/171-n-aberdeen-st'),
#  ('  Wicker Park',
#   'https://www.industriousoffice.com/l/chicago/wicker-park/1720-west-division-st'),
#  ('  Central Loop',
#   'https://www.industriousoffice.com/l/chicago/central-loop/231-s-lasalle'),
#  ('Indianapolis', 'https://www.industriousoffice.com/m/indianapolis'),
#  ('  Carmel City Center',
#   'https://www.industriousoffice.com/l/indianapolis/carmel-city/880-monon-green-boulevard'),
#  ('  Mass Ave',
#   'https://www.industriousoffice.com/l/indianapolis/350-massachusetts-ave'),
#  ('Boston', 'https://www.industriousoffice.com/m/boston'),
#  ('  Back Bay',
#   'https://www.industriousoffice.com/l/boston/back-bay/855-boylston-st'),
#  ('  Seaport',
#   'https://www.industriousoffice.com/l/boston/seaport/22-boston-wharf-rd'),
#  ('  Financial District',
#   'https://www.industriousoffice.com/l/boston/financial-district/100-summer-st'),
#  ('  Copley',
#   'https://www.industriousoffice.com/l/boston/copley/131-dartmouth-st'),
#  ('Minneapolis', 'https://www.industriousoffice.com/m/minneapolis'),
#  ('  North Loop',
#   'https://www.industriousoffice.com/l/minneapolis/north-loop/323-washington-avenue-north'),
#  ('  Downtown',
#   'https://www.industriousoffice.com/l/minneapolis/downtown/60-south-sixth-st'),
#  ('Kansas City',
#   'https://www.industriousoffice.com/l/kansas-city/country-club-plaza/420-nichols-rd'),
#  ('North Jersey', 'https://www.industriousoffice.com/m/north-jersey'),
#  ('  Newport Tower',
#   'https://www.industriousoffice.com/l/north-jersey/newport-tower/525-washington-blvd'),
#  ('  Short Hills',
#   'https://www.industriousoffice.com/l/north-jersey/mall-at-short-hills/1200-morris-turnpike'),
#  ('New York City', 'https://www.industriousoffice.com/m/new-york-city'),
#  ('  Tribeca',
#   'https://www.industriousoffice.com/l/new-york-city/tribeca/32-ave-of-the-americas'),
#  ('  WorkLife Office Suites by Industrious',
#   'https://www.industriousoffice.com/industrious-new-york-coworking/new-york-city-worklife-office-suites-powered-by-industrious'),
#  ('  West 30th',
#   'https://www.industriousoffice.com/l/new-york-city/west-30th/251-w-30th-street'),
#  ('  Brooklyn 1000 Dean',
#   'https://www.industriousoffice.com/l/new-york-city/brooklyn/1000-dean-st'),
#  ('  University Place',
#   'https://www.industriousoffice.com/l/new-york-city/university-place/41-east-11th-street'),
#  ('  261 Madison Ave',
#   'https://www.industriousoffice.com/l/new-york-city/261-madison-avenue'),
#  ('  Bryant Park off Fifth',
#   'https://www.industriousoffice.com/l/new-york-city/congregate-by-industrious/25-w-39th-st'),
#  ('  Carnegie Hall Tower',
#   'https://www.industriousoffice.com/l/new-york-city/carnegie-hall-tower/152-west-57th-st'),
#  ('  135 W 50th Street',
#   'https://www.industriousoffice.com/l/new-york-city/135-w-50th-st'),
#  ('  Industrious at Equinox',
#   'https://www.industriousoffice.com/l/new-york-city/equinox/31-hudson-yards'),
#  ('  Hana by Industrious at 3 World Trade Center',
#   'https://www.industriousoffice.com/l/new-york-city/hana-by-industrious-at-3-world-trade-center/175-greenwich-street'),
#  ('  Union Square',
#   'https://www.industriousoffice.com/l/new-york-city/union-square/215-park-avenue-s'),
#  ('  Brooklyn 594 Dean',
#   'https://www.industriousoffice.com/l/new-york-city/brooklyn/594-dean-st'),
#  ('  SoHo West',
#   'https://www.industriousoffice.com/l/new-york-city/soho-west/325-hudson-st'),
#  ('  Bryant Park on Broadway',
#   'https://www.industriousoffice.com/l/new-york-city/bryant-park/1411-broadway'),
#  ('Charlotte', 'https://www.industriousoffice.com/m/charlotte'),
#  ('  Uptown',
#   'https://www.industriousoffice.com/l/charlotte/uptown/101-s-tryon-st'),
#  ('  NoDa',
#   'https://www.industriousoffice.com/l/charlotte/noda/436-e-36th-street'),
#  ('Raleigh', 'https://www.industriousoffice.com/m/raleigh'),
#  ('  Chapel Hill  The Gwendolyn',
#   'https://www.industriousoffice.com/l/raleigh/chapel-hill-the-gwendolyn/101-glen-lennox'),
#  ('  Wells Fargo Capitol Center',
#   'https://www.industriousoffice.com/l/raleigh/wells-fargo-capitol-center/150-fayetteville-st'),
#  ('  Charter Square',
#   'https://www.industriousoffice.com/l/raleigh/charter-square/555-fayetteville-st'),
#  ('Columbus', 'https://www.industriousoffice.com/m/columbus'),
#  ('  The Sutton',
#   'https://www.industriousoffice.com/l/columbus/sutton/875-north-high-st'),
#  ('  The Joseph',
#   'https://www.industriousoffice.com/l/columbus/joseph/629-north-high-st'),
#  ('Portland',
#   'https://www.industriousoffice.com/l/portland/pioneer-square/811-sw-sixth-avenue'),
#  ('Philadelphia', 'https://www.industriousoffice.com/m/philadelphia'),
#  ('  Fashion District',
#   'https://www.industriousoffice.com/l/philadelphia/fashion-district/901-market-street'),
#  ('  Hana by Industrious at 1818 Market Street',
#   'https://www.industriousoffice.com/l/philadelphia/hana-by-industrious/1818-market-street'),
#  ('  Avenue of the Arts',
#   'https://www.industriousoffice.com/l/philadelphia/avenue-of-the-arts/230-s-broad-st'),
#  ('  Two Liberty Place',
#   'https://www.industriousoffice.com/l/philadelphia/two-liberty-place/50-s-sixteenth-st'),
#  ('Pittsburgh', 'https://www.industriousoffice.com/m/pittsburgh'),
#  ('  PPG Place',
#   'https://www.industriousoffice.com/l/pittsburgh/ppg-place/one-ppg-place'),
#  ('  Liberty Center',
#   'https://www.industriousoffice.com/l/pittsburgh/liberty-center/1001-liberty-ave'),
#  ('Nashville', 'https://www.industriousoffice.com/m/nashville'),
#  ('  Downtown',
#   'https://www.industriousoffice.com/l/nashville/downtown/414-union-st'),
#  ('  Gulch',
#   'https://www.industriousoffice.com/l/nashville/gulch/1033-demonbreun-st'),
#  ('Austin', 'https://www.industriousoffice.com/m/austin'),
#  ('  9th and Congress',
#   'https://www.industriousoffice.com/l/austin/9th-congress/823-congress-ave'),
#  ('  5th and Colorado',
#   'https://www.industriousoffice.com/l/austin/5th-colorado/201-west-fifth-st'),
#  ('  San Jacinto Blvd',
#   'https://www.industriousoffice.com/l/austin/98-san-jacinto-blvd'),
#  ('Dallas — Fort Worth', 'https://www.industriousoffice.com/m/dallas'),
#  ('  Dallas Farmers Market',
#   'https://www.industriousoffice.com/l/dallas/farmers-market/910-south-pearl-expressway'),
#  ('  Hana by Industrious at Park District',
#   'https://www.industriousoffice.com/l/dallas/hana-by-industrious-at-park-district/2121-n-pearl-street'),
#  ('  Plano',
#   'https://www.industriousoffice.com/l/dallas/plano/7250-dallas-pkwy'),
#  ('  Arts District',
#   'https://www.industriousoffice.com/l/dallas/arts-district/1722-routh-st'),
#  ('Houston', 'https://www.industriousoffice.com/m/houston'),
#  ('', 'https://www.industriousoffice.com/l/houston/2101-citywest-blvd'),
#  ('Salt Lake City', 'https://www.industriousoffice.com/m/slc'),
#  ('  The Square with Industrious',
#   'https://www.industriousoffice.com/l/slc/the-square/136-s-main-st'),
#  ('Seattle', 'https://www.industriousoffice.com/m/seattle'),
#  ('  Downtown',
#   'https://www.industriousoffice.com/l/seattle/downtown/2033-sixth-avenue'),
#  ('  Bellevue',
#   'https://www.industriousoffice.com/l/seattle/bellevue/500-108th-avenue-ne')]

# %%
len(loc_links_ls)
# Out:
# 276

# %% [markdown]
# ## Download images from each location page

# %%
# for each location page, get its image links
def get_img_links(url):
    
    page = BeautifulSoup(requests.get(url).content,'lxml')
    
    img_links_ls = list()
    images = page.find_all('picture',{'class':'embed-responsive-item'})
    for i in images:
        link = i.find('img',{'class':'webpexpress-processed'}).get('src')
        img_links_ls.append(link[:-7])
        
    return img_links_ls

# %%
# get all locations' image links
all_img_links = list()
for loc in loc_links_ls:
    if 'www.industriousoffice.com/l' in loc[1]:
        img_links_ls = get_img_links(loc[1])
        all_img_links.append((loc[0],img_links_ls))

# %%
all_img_links[0]
# Out:
# ('Scottsdale  Fashion Square',
#  ['https://www.industriousoffice.com/wp-content/uploads/2019/06/Scottsdale-FS-Gallery8-1230x692.jpg',
#   'https://www.industriousoffice.com/wp-content/uploads/2020/12/scottsdale_3.jpg',
#   'https://www.industriousoffice.com/wp-content/uploads/2020/12/Office8-1230x692.jpg',
#   'https://www.industriousoffice.com/wp-content/uploads/2019/06/Scottsdale-FS-Gallery4-1-1230x692.jpg',
#   'https://www.industriousoffice.com/wp-content/uploads/2020/12/WellnessRoom6-1230x692.jpg',
#   'https://www.industriousoffice.com/wp-content/uploads/2020/12/Scottsdale-FashionSquare-Common-1230x692.jpg',
#   'https://www.industriousoffice.com/wp-content/uploads/2020/12/Scottsdale-FashionSquare-Entry-1230x692.jpg'])

# %%
# save all images: one file for one location
img_directory = 'image'
industrious_directory = 'image/industrious'

if not os.path.exists(img_directory):
    os.mkdir(img_directory)
if not os.path.exists(industrious_directory):
    os.mkdir(industrious_directory)

for loc_img in all_img_links:
    for i,link in enumerate(loc_img[1]):
        loc = re.sub('[\s+]', '', loc_img[0])
        img = requests.get(link).content
        if not os.path.exists(industrious_directory+'/'+loc):
            os.mkdir(industrious_directory+'/'+loc)
        with open(industrious_directory+'/'+loc+'/%d.jpg'%i,'wb') as f:
            f.write(img)

# %%
# record tag for each image
img_tag_ls = list()

for loc in loc_links_ls:
    if 'www.industriousoffice.com/l' in loc[1]:
        loc_name = re.sub('[\s+]', '', loc[0])
        loc_page = BeautifulSoup(requests.get(loc[1]).content,'lxml')
        tag_ls = list()
        for t in loc_page.find_all('p',{'class':'gallery-caption'}):
            i = loc_page.find_all('p',{'class':'gallery-caption'}).index(t)
            tag_ls.append((industrious_directory+'/'+loc_name+'/%d.jpg'%i, t.get_text()))
    img_tag_ls.extend(tag_ls)

# %%
df = pd.DataFrame(img_tag_ls, columns=['img_path', 'tag'])
df.head()
# Out:
#                                           img_path  \
# 0  image/industrious/ScottsdaleFashionSquare/0.jpg
# 1  image/industrious/ScottsdaleFashionSquare/1.jpg
# 2  image/industrious/ScottsdaleFashionSquare/2.jpg
# 3  image/industrious/ScottsdaleFashionSquare/3.jpg
# 4  image/industrious/ScottsdaleFashionSquare/4.jpg
#
#                              tag
# 0                    Common area
# 1                           Cafe
# 2  Example shown: Private office
# 3                Conference room
# 4   Example shown: Wellness room

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   img_path  1430 non-null   object
#  1   tag       1430 non-null   object
# dtypes: object(2)
# memory usage: 22.5+ KB

# %%
df.to_csv("industrious_images_tag.csv")

# %% [markdown]
# ## Classify into outdoor, indoor, gym&swimming pool, floorplan

# %%
df = pd.read_csv("industrious_images_tag.csv")

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#                                           img_path  \
# 0  image/industrious/ScottsdaleFashionSquare/0.jpg
# 1  image/industrious/ScottsdaleFashionSquare/1.jpg
# 2  image/industrious/ScottsdaleFashionSquare/2.jpg
# 3  image/industrious/ScottsdaleFashionSquare/3.jpg
# 4  image/industrious/ScottsdaleFashionSquare/4.jpg
#
#                              tag
# 0                    Common area
# 1                           Cafe
# 2  Example shown: Private office
# 3                Conference room
# 4   Example shown: Wellness room

# %%
df['tag'].value_counts()
# Out:
# Common area                                                                             344
# Conference room                                                                         146
# Private office                                                                          106
# Cafe                                                                                     63
# Example shown: Conference room                                                           63
#                                                                                        ...
# This meeting room is just the right size for a small team huddle.                         2
# Outdoor terrace                                                                           2
# Outdoor Space                                                                             2
# Carlyle Tower fitness center                                                              2
# Members receive complimentary breakfast and an afternoon snack daily in the kitchen.      2
# Name: tag, Length: 113, dtype: int64

# %%
tag_ls = list(df['tag'].unique())

# %%
tag_ls
# Out:
# ['Common area',
#  'Cafe',
#  'Example shown: Private office',
#  'Conference room',
#  'Example shown: Wellness room',
#  'Mall entrance',
#  'Common Area',
#  'Office',
#  'Conference Room',
#  'Café',
#  'Wellness Room',
#  'Outdoor Space',
#  'Example shown: Common area',
#  'Example shown: Office',
#  'Example shown: Cafe',
#  'Example shown: Conference room',
#  'Example shown: Phone booths',
#  'Private office',
#  'Phone booths',
#  'Wellness room',
#  'Canvas suite',
#  'Event space',
#  'Fitness center',
#  'Campus basketball court',
#  'Campus lounge area',
#  nan,
#  'Example shown: Focus area',
#  'Reception',
#  'Café and lounge',
#  'Reception and common area',
#  'Large team suite',
#  'Building lobby',
#  'Tenant lounge',
#  'Library',
#  'Lounge and conference rooms',
#  'Example shown: Café',
#  'Outdoor terrace',
#  'Lounge',
#  'Front desk',
#  'Focus area',
#  'Industrious entrance and building lobby',
#  'Carlyle Tower fitness center',
#  'Carlyle Tower tenant lounge',
#  'Carlyle Tower conference center',
#  'Huddle room',
#  'Rooftop terrace | Image courtesy of Carr Properties',
#  'Fitness center | Image courtesy of Carr Properties',
#  'Example: Conference room',
#  'Example: Office',
#  'Lobby and entrance',
#  'Industrious 200 Central Ave, a flexible workplace in St. Petersburg, Florida.',
#  'Suites at Industrious 200 Central Ave. afford views of downtown Tampa.',
#  'The cafe and kitchen, where members can grab coffee and breakfast in the morning.',
#  'Members can book conference rooms like this one, which come equipped for presentations or video calls.',
#  'There are plenty of shared spaces where members can meet each other or gather with their teams.',
#  'Reception area',
#  'Phone booths by Room are specially designed to be soundproof and private.',
#  'Plants —\xa0which have been shown to reduce stress — can be found throughout the workplace.',
#  'This wellness room contains a comfortable chair, mini fridge, and sink, and can be locked for privacy.',
#  'Outdoor space',
#  'Lobby',
#  'Get a peek inside Industrious Buckhead in Atlanta.',
#  'Private offices and suites overlook Atlanta’s Buckhead neighborhood.',
#  'This meeting room is just the right size for a small team huddle. ',
#  'Members can work or unwind in the location’s lounge.',
#  'Members can book conference rooms with whiteboards, A/V equipment, and other amenities.',
#  'ROOM Meeting Room and Phone Booth',
#  'Cafe and lounge',
#  'Offices come fully-furnished with desks and Herman Miller chairs.',
#  'Suite',
#  'Wellness rooom',
#  'Café and Lounge',
#  'Example shown: Private Office',
#  'Canvas Suite',
#  'Example shown: Wellness Room',
#  'Outdoor area',
#  'Discover all there is to do near Industrious Back Bay in Boston.',
#  'Cafe\n',
#  'Example shown: Suite',
#  'Conference rooms',
#  'Example shown: Boardroom',
#  'Phone rooms',
#  'Entry and reception',
#  'Lounge and reception',
#  'Boardroom',
#  'View from terrace',
#  'Conference rooms of various sizes come with whiteboards, A/V equipment, and other amenities.',
#  'Club 135 entrance',
#  'Club 135 lounge',
#  'Club 135 meeting and event space',
#  'Club 135 meeting space',
#  'Club 135 amenity',
#  'Hallway and lounge',
#  'After working from home for months, many miss the office.',
#  'Board room',
#  'Views',
#  'Common area and phone booths',
#  'Building amenity: Conference center',
#  'Building amenity: Fitness center',
#  'Greenery not only adds warmth to the location but also has been shown to reduce stress.',
#  'Architectural detail',
#  'Office have plenty of natural light and afford views of the city.',
#  'There are a ton of shops and restaurants just outside the location.',
#  'Amenities',
#  'The common area for Industrious 9th and Congress in Austin, Texas.',
#  'Offices and suites at Industrious 9th and Congress overlook downtown Austin.',
#  'A conference room equipped with A/V for presentations and mixed-presence meetings.',
#  'Members have access to a cafe and lounge.',
#  'Members receive complimentary breakfast and an afternoon snack daily in the kitchen.',
#  'One of Industrious 9th and Congress’ spacious suites.',
#  'This huddle room is ideal for small gatherings and brainstorms.',
#  'Entrance',
#  'Phone room',
#  'Downtown views']

# %%
# df.loc[df["tag"].isnull()]
df.loc[df['tag'] == "Building amenity: Fitness center"]
# Out:
#                                              img_path  \
# 572   image/industrious/WellsFargoCapitolCenter/9.jpg
# 1290  image/industrious/WellsFargoCapitolCenter/9.jpg
#
#                                    tag
# 572   Building amenity: Fitness center
# 1290  Building amenity: Fitness center
